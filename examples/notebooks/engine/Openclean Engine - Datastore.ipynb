# %% [markdown]
# # Engine - Datastore
#
# This is an example notebook to demonstrate how to update and maintain dataset versions using the openclean engine.

# %%
# Crete an persistent instance of the openclean engine. All the data
# files will be maintained in a sub-folder of the current working directory.

from openclean.engine.base import DB

db = DB(basedir='./archive', create=True)

# %%
# Download an test dataset from the Socrata API:
# 'Bidders List Master' from domain data.vermont.gov

from openclean.data.source.socrata import Socrata

df = Socrata().dataset('y343-ur4c').load()
df
# Out:
#            Date                                   Title or Project  \
# 0    07/26/2017                               HE - NARCAN 4MG 7.25
# 1    08/22/2017                                   Lab Bend Fixture
# 2    09/19/2017                                  FTA Cards for DPS
# 3    09/26/2017                       02140-785 - Rescue Equipment
# 4    09/20/2017  BGS - 170078 Trush Parking Lot Paving Repairs ...
# ..          ...                                                ...
# 190  08/09/2017     BGS - AHS Janitorial Services  - St Albans, VT
# 191  09/06/2017      BGS - A & E Window Restoration - 133 State St
# 192  09/07/2017                                    VDH - Car Seats
# 193  07/24/2017                 RFP DMV Registration Renewal Forms
# 194  08/03/2017           02140-331 - Enclosed snowmobile trailers
#
#                     Bidders Name              City State  \
# 0                   Adapt Pharma            RADNOR    PA
# 1                            NaN               NaN   NaN
# 2                  GE Healthcare        Marborough    MA
# 3                 Reynolds & Son             Barre    VT
# 4               S T Paving , Inc         Waterbury    VT
# ..                           ...               ...   ...
# 190     Loso's Professional J.S.  South Burlington    VT
# 191  VT Architects Collaborative          Randolph    VT
# 192                     Even Flo           Cullman    AL
# 193                 RR Donnelley             Derry    NH
# 194       Perfection Motorsports          Richmond    VT
#
#                                         Location 1
# 0              RADNOR, PA\n(40.038043, -75.344449)
# 1                                              NaN
# 2                                   Marborough, MA
# 3               Barre, VT\n(44.200603, -72.505569)
# 4           Waterbury, VT\n(44.334602, -72.753189)
# ..                                             ...
# 190  South Burlington, VT\n(44.468286, -73.171594)
# 191          Randolph, VT\n(43.925266, -72.665754)
# 192           Cullman, AL\n(34.173753, -86.843115)
# 193             Derry, NH\n(42.881978, -71.324171)
# 194          Richmond, VT\n(44.405247, -72.992905)
#
# [195 rows x 6 columns]

# %%
# Create a new persistent dataset archive from the downloaded
# data frame in the openclean engine database.

df = db.create(df, name='bidders', primary_key='Title or Project')

# %%
# Delete rows where bidder's name is empty.

from openclean.function.eval.null import IsEmpty
from openclean.operator.transform.filter import delete

db.commit(name='bidders', df=delete(df, IsEmpty('Bidders Name')))
# Out:
#            Date                                   Title or Project  \
# 143  07/26/2017                               HE - NARCAN 4MG 7.25
# 138  09/19/2017                                  FTA Cards for DPS
# 24   09/26/2017                       02140-785 - Rescue Equipment
# 59   09/20/2017  BGS - 170078 Trush Parking Lot Paving Repairs ...
# 43   08/25/2017                         AGR - Laboratory Epuipment
# ..          ...                                                ...
# 64   08/09/2017     BGS - AHS Janitorial Services  - St Albans, VT
# 62   09/06/2017      BGS - A & E Window Restoration - 133 State St
# 179  09/07/2017                                    VDH - Car Seats
# 159  07/24/2017                 RFP DMV Registration Renewal Forms
# 3    08/03/2017           02140-331 - Enclosed snowmobile trailers
#
#                     Bidders Name              City State  \
# 143                 Adapt Pharma            RADNOR    PA
# 138                GE Healthcare        Marborough    MA
# 24                Reynolds & Son             Barre    VT
# 59              S T Paving , Inc         Waterbury    VT
# 43            Daigger Scientific      Vernon Hills    IL
# ..                           ...               ...   ...
# 64      Loso's Professional J.S.  South Burlington    VT
# 62   VT Architects Collaborative          Randolph    VT
# 179                     Even Flo           Cullman    AL
# 159                 RR Donnelley             Derry    NH
# 3         Perfection Motorsports          Richmond    VT
#
#                                         Location 1
# 143            RADNOR, PA\n(40.038043, -75.344449)
# 138                                 Marborough, MA
# 24              Barre, VT\n(44.200603, -72.505569)
# 59          Waterbury, VT\n(44.334602, -72.753189)
# 43       Vernon Hills, IL\n(42.238635, -87.959562)
# ..                                             ...
# 64   South Burlington, VT\n(44.468286, -73.171594)
# 62           Randolph, VT\n(43.925266, -72.665754)
# 179           Cullman, AL\n(34.173753, -86.843115)
# 159             Derry, NH\n(42.881978, -71.324171)
# 3            Richmond, VT\n(44.405247, -72.992905)
#
# [194 rows x 6 columns]

# %%
# Register existing string functions as 'user defined functions'.

db.register.eval()(str.lower)
db.register.eval()(str.upper)
db.register.eval()(str.capitalize)

# Print function registry.
db.library.functions().to_listing()
# Out:
# [{'name': 'lower',
#   'namespace': None,
#   'description': Type help() for interactive help, or help(object) for help about object.,
#   'columns': 1,
#   'outputs': 1,
#   'parameters': []},
#  {'name': 'upper',
#   'namespace': None,
#   'description': Type help() for interactive help, or help(object) for help about object.,
#   'columns': 1,
#   'outputs': 1,
#   'parameters': []},
#  {'name': 'capitalize',
#   'namespace': None,
#   'description': Type help() for interactive help, or help(object) for help about object.,
#   'columns': 1,
#   'outputs': 1,
#   'parameters': []}]

# %%
# Convert values in the 'Bidders Name' column to lower case.

db.dataset(name='bidders').update(columns='Bidders Name', func=db.library.functions().get('lower'))
# Out:
#            Date                                   Title or Project  \
# 143  07/26/2017                               HE - NARCAN 4MG 7.25
# 138  09/19/2017                                  FTA Cards for DPS
# 24   09/26/2017                       02140-785 - Rescue Equipment
# 59   09/20/2017  BGS - 170078 Trush Parking Lot Paving Repairs ...
# 43   08/25/2017                         AGR - Laboratory Epuipment
# ..          ...                                                ...
# 64   08/09/2017     BGS - AHS Janitorial Services  - St Albans, VT
# 62   09/06/2017      BGS - A & E Window Restoration - 133 State St
# 179  09/07/2017                                    VDH - Car Seats
# 159  07/24/2017                 RFP DMV Registration Renewal Forms
# 3    08/03/2017           02140-331 - Enclosed snowmobile trailers
#
#                     Bidders Name              City State  \
# 143                 adapt pharma            RADNOR    PA
# 138                ge healthcare        Marborough    MA
# 24                reynolds & son             Barre    VT
# 59              s t paving , inc         Waterbury    VT
# 43            daigger scientific      Vernon Hills    IL
# ..                           ...               ...   ...
# 64      loso's professional j.s.  South Burlington    VT
# 62   vt architects collaborative          Randolph    VT
# 179                     even flo           Cullman    AL
# 159                 rr donnelley             Derry    NH
# 3         perfection motorsports          Richmond    VT
#
#                                         Location 1
# 143            RADNOR, PA\n(40.038043, -75.344449)
# 138                                 Marborough, MA
# 24              Barre, VT\n(44.200603, -72.505569)
# 59          Waterbury, VT\n(44.334602, -72.753189)
# 43       Vernon Hills, IL\n(42.238635, -87.959562)
# ..                                             ...
# 64   South Burlington, VT\n(44.468286, -73.171594)
# 62           Randolph, VT\n(43.925266, -72.665754)
# 179           Cullman, AL\n(34.173753, -86.843115)
# 159             Derry, NH\n(42.881978, -71.324171)
# 3            Richmond, VT\n(44.405247, -72.992905)
#
# [194 rows x 6 columns]

# %%
# Show operations in the current dataset log.

for op in db.dataset('bidders').log():
    print(op.descriptor)
# Out:
# {'optype': 'load', 'columns': None}
# {'optype': 'commit', 'columns': None}
# {'optype': 'update', 'columns': ['Bidders Name'], 'name': 'lower'}

# %%
# Add a user-defined function as a simple column-operator.
# register.eval adds a method to the object that is returned
# by db.apply that currently expects a single argument named
# 'columns' which specifies the column(s) on which the registered
# function is applied (evaluated) to create a modified dataset.

@db.register.eval('zigzag')
def zigzag_case(value):
    """Take a given string and return a string where
    upper and lower cases alternate.
    """
    result = ''
    functions = [str.upper, str.lower]
    i = 0
    for c in str(value):
        f = functions[i]
        i = (i + 1) % 2
        result += f(c)
    return result

# %% [markdown]
# ## Notebook Spreadsheet UI
#
# The following steps simulate some of the interactions that a user has with a dataset sample via the spreadsheet UI for Jupyter Notebooks.

# %%
# Take a dataset sample of 10 rows.

db.sample(name='bidders', n=10, random_state=43)
# Out:
#            Date                                   Title or Project  \
# 66   08/09/2017  BGS - AHS Janitorial Services - St. Johnsbury, VT
# 13   08/14/2017                    02140-779 - Firefighter Helmets
# 124  08/04/2017                                   Ballistic Panels
# 32   09/21/2017                            02150-91 - Electric ATV
# 37   08/01/2017                    02170-776 - 14" structural boot
# 101  08/02/2017   BGS - Retainer - General Enviromental Consulting
# 80   09/06/2017               BGS - Curatorial Assistance Services
# 136  08/18/2017  Division of Emergency Management Mass Notifica...
# 154  09/08/2017      Print Shop Digital Printing Workflow Solution
# 163  07/27/2017  Reconstruction  & Improvements Roxbury Fish Cu...
#
#                      Bidders Name                  City State  \
# 66        top carpet cleaning llc  St. Johnsbury Center    VT
# 13   bergeron protective clothing                 Epsom    NH
# 124       executive wood products              Sullivan    MO
# 32                         aagean            Stoughton     MA
# 37   bergeron protective clothing                 Epsom    NH
# 101             kd associates inc      South Burlington    VT
# 80                  allyson evans                Calais    VT
# 136                    everbridge            Burlington    MA
# 154                         canon      South Burlington    VT
# 163           t buck construction                Turner    ME
#
#                                             Location 1
# 66   St. Johnsbury Center, VT\n(44.456699, -72.016098)
# 13                  Epsom, NH\n(43.222832, -71.332095)
# 124               Sullivan, MO\n(38.213599, -91.16411)
# 32              Stoughton, MA\n(42.125465, -71.102172)
# 37                  Epsom, NH\n(43.222832, -71.332095)
# 101      South Burlington, VT\n(44.468286, -73.171594)
# 80                 Calais, VT\n(44.389374, -72.512604)
# 136            Burlington, MA\n(42.504986, -71.195832)
# 154      South Burlington, VT\n(44.468286, -73.171594)
# 163                 Turner, ME\n(44.256483, -70.25625)

# %%
# Capitalize values in the 'Bidders Name' columns.

db.dataset(name='bidders').update(columns='Bidders Name', func=db.library.functions().get('capitalize'))
# Out:
#           Date                                   Title or Project  \
# 13  08/09/2017  BGS - AHS Janitorial Services - St. Johnsbury, VT
# 10  08/14/2017                    02140-779 - Firefighter Helmets
# 16  08/04/2017                                   Ballistic Panels
# 11  09/21/2017                            02150-91 - Electric ATV
# 12  08/01/2017                    02170-776 - 14" structural boot
# 15  08/02/2017   BGS - Retainer - General Enviromental Consulting
# 14  09/06/2017               BGS - Curatorial Assistance Services
# 17  08/18/2017  Division of Emergency Management Mass Notifica...
# 18  09/08/2017      Print Shop Digital Printing Workflow Solution
# 19  07/27/2017  Reconstruction  & Improvements Roxbury Fish Cu...
#
#                     Bidders Name                  City State  \
# 13       Top carpet cleaning llc  St. Johnsbury Center    VT
# 10  Bergeron protective clothing                 Epsom    NH
# 16       Executive wood products              Sullivan    MO
# 11                        Aagean            Stoughton     MA
# 12  Bergeron protective clothing                 Epsom    NH
# 15             Kd associates inc      South Burlington    VT
# 14                 Allyson evans                Calais    VT
# 17                    Everbridge            Burlington    MA
# 18                         Canon      South Burlington    VT
# 19           T buck construction                Turner    ME
#
#                                            Location 1
# 13  St. Johnsbury Center, VT\n(44.456699, -72.016098)
# 10                 Epsom, NH\n(43.222832, -71.332095)
# 16               Sullivan, MO\n(38.213599, -91.16411)
# 11             Stoughton, MA\n(42.125465, -71.102172)
# 12                 Epsom, NH\n(43.222832, -71.332095)
# 15      South Burlington, VT\n(44.468286, -73.171594)
# 14                Calais, VT\n(44.389374, -72.512604)
# 17            Burlington, MA\n(42.504986, -71.195832)
# 18      South Burlington, VT\n(44.468286, -73.171594)
# 19                 Turner, ME\n(44.256483, -70.25625)

# %%
# Apply the zig-zag function to column 'City'

db.dataset(name='bidders').update(columns='City', func=zigzag_case)
# Out:
#           Date                                   Title or Project  \
# 0   08/09/2017  BGS - AHS Janitorial Services - St. Johnsbury, VT
# 20  08/14/2017                    02140-779 - Firefighter Helmets
# 25  08/04/2017                                   Ballistic Panels
# 21  09/21/2017                            02150-91 - Electric ATV
# 22  08/01/2017                    02170-776 - 14" structural boot
# 24  08/02/2017   BGS - Retainer - General Enviromental Consulting
# 23  09/06/2017               BGS - Curatorial Assistance Services
# 26  08/18/2017  Division of Emergency Management Mass Notifica...
# 27  09/08/2017      Print Shop Digital Printing Workflow Solution
# 28  07/27/2017  Reconstruction  & Improvements Roxbury Fish Cu...
#
#                     Bidders Name                  City State  \
# 0        Top carpet cleaning llc  St. JoHnSbUrY CeNtEr    VT
# 20  Bergeron protective clothing                 EpSoM    NH
# 25       Executive wood products              SuLlIvAn    MO
# 21                        Aagean            StOuGhToN     MA
# 22  Bergeron protective clothing                 EpSoM    NH
# 24             Kd associates inc      SoUtH BuRlInGtOn    VT
# 23                 Allyson evans                CaLaIs    VT
# 26                    Everbridge            BuRlInGtOn    MA
# 27                         Canon      SoUtH BuRlInGtOn    VT
# 28           T buck construction                TuRnEr    ME
#
#                                            Location 1
# 0   St. Johnsbury Center, VT\n(44.456699, -72.016098)
# 20                 Epsom, NH\n(43.222832, -71.332095)
# 25               Sullivan, MO\n(38.213599, -91.16411)
# 21             Stoughton, MA\n(42.125465, -71.102172)
# 22                 Epsom, NH\n(43.222832, -71.332095)
# 24      South Burlington, VT\n(44.468286, -73.171594)
# 23                Calais, VT\n(44.389374, -72.512604)
# 26            Burlington, MA\n(42.504986, -71.195832)
# 27      South Burlington, VT\n(44.468286, -73.171594)
# 28                 Turner, ME\n(44.256483, -70.25625)

# %%
# Show operations in the current dataset log (recipe). Note that
# each log entry has a unique identifier that is used to reference
# the represented dataset snapshot in checkout() and rollback()
# operations.

snapshots = list()
for op in db.dataset('bidders').log():
    print('{} {}'.format(op.identifier, op.descriptor))
    snapshots.append(op.identifier)
# Out:
# d863328a3da645f5b304e51414e8897d {'optype': 'sample', 'columns': None, 'arguments': [{'name': 'n', 'value': 10}, {'name': 'randomState', 'value': 43}]}
# a0440be6e67641639342cdbdf4ea7e78 {'optype': 'update', 'columns': ['Bidders Name'], 'name': 'capitalize'}
# 3c9336090c444c86a4a28b51855456e3 {'optype': 'update', 'columns': ['City'], 'name': 'zigzag'}

# %%
# Print snapshot that resulted from the second operation
# in the recipe, i.e., the capitalize operation on the
# 'Bidders Name'. City names should not be zig-zag in this
# snapshot.

db.dataset('bidders').checkout(snapshots[1])
# Out:
#           Date                                   Title or Project  \
# 13  08/09/2017  BGS - AHS Janitorial Services - St. Johnsbury, VT
# 10  08/14/2017                    02140-779 - Firefighter Helmets
# 16  08/04/2017                                   Ballistic Panels
# 11  09/21/2017                            02150-91 - Electric ATV
# 12  08/01/2017                    02170-776 - 14" structural boot
# 15  08/02/2017   BGS - Retainer - General Enviromental Consulting
# 14  09/06/2017               BGS - Curatorial Assistance Services
# 17  08/18/2017  Division of Emergency Management Mass Notifica...
# 18  09/08/2017      Print Shop Digital Printing Workflow Solution
# 19  07/27/2017  Reconstruction  & Improvements Roxbury Fish Cu...
#
#                     Bidders Name                  City State  \
# 13       Top carpet cleaning llc  St. Johnsbury Center    VT
# 10  Bergeron protective clothing                 Epsom    NH
# 16       Executive wood products              Sullivan    MO
# 11                        Aagean            Stoughton     MA
# 12  Bergeron protective clothing                 Epsom    NH
# 15             Kd associates inc      South Burlington    VT
# 14                 Allyson evans                Calais    VT
# 17                    Everbridge            Burlington    MA
# 18                         Canon      South Burlington    VT
# 19           T buck construction                Turner    ME
#
#                                            Location 1
# 13  St. Johnsbury Center, VT\n(44.456699, -72.016098)
# 10                 Epsom, NH\n(43.222832, -71.332095)
# 16               Sullivan, MO\n(38.213599, -91.16411)
# 11             Stoughton, MA\n(42.125465, -71.102172)
# 12                 Epsom, NH\n(43.222832, -71.332095)
# 15      South Burlington, VT\n(44.468286, -73.171594)
# 14                Calais, VT\n(44.389374, -72.512604)
# 17            Burlington, MA\n(42.504986, -71.195832)
# 18      South Burlington, VT\n(44.468286, -73.171594)
# 19                 Turner, ME\n(44.256483, -70.25625)

# %%
# Remove the zig-zag operation from the dataset history
# by rolling back to the previous operation.

db.dataset('bidders').rollback(snapshots[1])
# Out:
#           Date                                   Title or Project  \
# 13  08/09/2017  BGS - AHS Janitorial Services - St. Johnsbury, VT
# 10  08/14/2017                    02140-779 - Firefighter Helmets
# 16  08/04/2017                                   Ballistic Panels
# 11  09/21/2017                            02150-91 - Electric ATV
# 12  08/01/2017                    02170-776 - 14" structural boot
# 15  08/02/2017   BGS - Retainer - General Enviromental Consulting
# 14  09/06/2017               BGS - Curatorial Assistance Services
# 17  08/18/2017  Division of Emergency Management Mass Notifica...
# 18  09/08/2017      Print Shop Digital Printing Workflow Solution
# 19  07/27/2017  Reconstruction  & Improvements Roxbury Fish Cu...
#
#                     Bidders Name                  City State  \
# 13       Top carpet cleaning llc  St. Johnsbury Center    VT
# 10  Bergeron protective clothing                 Epsom    NH
# 16       Executive wood products              Sullivan    MO
# 11                        Aagean            Stoughton     MA
# 12  Bergeron protective clothing                 Epsom    NH
# 15             Kd associates inc      South Burlington    VT
# 14                 Allyson evans                Calais    VT
# 17                    Everbridge            Burlington    MA
# 18                         Canon      South Burlington    VT
# 19           T buck construction                Turner    ME
#
#                                            Location 1
# 13  St. Johnsbury Center, VT\n(44.456699, -72.016098)
# 10                 Epsom, NH\n(43.222832, -71.332095)
# 16               Sullivan, MO\n(38.213599, -91.16411)
# 11             Stoughton, MA\n(42.125465, -71.102172)
# 12                 Epsom, NH\n(43.222832, -71.332095)
# 15      South Burlington, VT\n(44.468286, -73.171594)
# 14                Calais, VT\n(44.389374, -72.512604)
# 17            Burlington, MA\n(42.504986, -71.195832)
# 18      South Burlington, VT\n(44.468286, -73.171594)
# 19                 Turner, ME\n(44.256483, -70.25625)

# %%
# Show remaining operations in the current dataset log.

for op in db.dataset('bidders').log():
    print('{} {}'.format(op.identifier, op.descriptor))
    snapshots.append(op.identifier)
# Out:
# d863328a3da645f5b304e51414e8897d {'optype': 'sample', 'columns': None, 'arguments': [{'name': 'n', 'value': 10}, {'name': 'randomState', 'value': 43}]}
# a0440be6e67641639342cdbdf4ea7e78 {'optype': 'update', 'columns': ['Bidders Name'], 'name': 'capitalize'}

# %%
# Apply changes to the full dataset.

db.checkout('bidders', commit=True)
# Out:
#            Date                                   Title or Project  \
# 143  07/26/2017                               HE - NARCAN 4MG 7.25
# 138  09/19/2017                                  FTA Cards for DPS
# 24   09/26/2017                       02140-785 - Rescue Equipment
# 59   09/20/2017  BGS - 170078 Trush Parking Lot Paving Repairs ...
# 43   08/25/2017                         AGR - Laboratory Epuipment
# ..          ...                                                ...
# 64   08/09/2017     BGS - AHS Janitorial Services  - St Albans, VT
# 62   09/06/2017      BGS - A & E Window Restoration - 133 State St
# 179  09/07/2017                                    VDH - Car Seats
# 159  07/24/2017                 RFP DMV Registration Renewal Forms
# 3    08/03/2017           02140-331 - Enclosed snowmobile trailers
#
#                     Bidders Name              City State  \
# 143                 Adapt pharma            RADNOR    PA
# 138                Ge healthcare        Marborough    MA
# 24                Reynolds & son             Barre    VT
# 59              S t paving , inc         Waterbury    VT
# 43            Daigger scientific      Vernon Hills    IL
# ..                           ...               ...   ...
# 64      Loso's professional j.s.  South Burlington    VT
# 62   Vt architects collaborative          Randolph    VT
# 179                     Even flo           Cullman    AL
# 159                 Rr donnelley             Derry    NH
# 3         Perfection motorsports          Richmond    VT
#
#                                         Location 1
# 143            RADNOR, PA\n(40.038043, -75.344449)
# 138                                 Marborough, MA
# 24              Barre, VT\n(44.200603, -72.505569)
# 59          Waterbury, VT\n(44.334602, -72.753189)
# 43       Vernon Hills, IL\n(42.238635, -87.959562)
# ..                                             ...
# 64   South Burlington, VT\n(44.468286, -73.171594)
# 62           Randolph, VT\n(43.925266, -72.665754)
# 179           Cullman, AL\n(34.173753, -86.843115)
# 159             Derry, NH\n(42.881978, -71.324171)
# 3            Richmond, VT\n(44.405247, -72.992905)
#
# [194 rows x 6 columns]

# %%
# Show operations in the resulting dataset log.

for op in db.dataset('bidders').log():
    print(op.descriptor)
# Out:
# {'optype': 'load', 'columns': None}
# {'optype': 'commit', 'columns': None}
# {'optype': 'update', 'columns': ['Bidders Name'], 'name': 'lower'}
# {'optype': 'update', 'columns': ['Bidders Name'], 'name': 'capitalize'}
