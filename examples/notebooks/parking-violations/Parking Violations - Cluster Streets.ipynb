# %% [markdown]
# # Identifiy Potential Misspellings of Street Names
#
# Find groups of different street names that might be alternative representations of the same street. This is an example for the key collision clustering supported by **openclean**. Uses the **NYC Parking Violations Issued - Fiscal Year 2014** dataset.

# %%
# Download the full 'DOB Job Application Fiings' dataset.

import gzip

from openclean.data.source.socrata import Socrata

datafile = './jt7v-77mi.tsv.gz'

#with gzip.open(datafile, 'wb') as f:
#    ds = Socrata().dataset('jt7v-77mi')
#    ds.write(f)


# As an alternative, you can also use the smaller dataset sample that is
# included in the repository.
#
# datafile = './data/jt7v-77mi.tsv.gz'

# %%
# Get distinct set of street names. By computing the distinct set of
# street names first we avoid computing keys for each distinct street
# name multiple times.

from openclean.pipeline import stream

df = stream(datafile)

streets = df.select('Street').distinct()

print('{} distinct streets (for {} total values)'.format(len(streets), sum(streets.values())))
# Out:
# 115567 distinct streets (for 9100278 total values)

# %%
# Cluster street names using key collision (with the default key generator).
# Remove clusters that contain less than seven distinct values (for display
# purposes). Use multiple threads (4) to generate value keys in parallel.

from openclean.cluster.key import key_collision

# Minimum cluster size. Use seven as defaultfor the full dataset (to limit
# the number of clusters that are printed in the next cell).
minsize = 7

# Use minimum cluster size of 2 when using the dataset sample
# minsize = 2

clusters = key_collision(values=streets, minsize=minsize, threads=4)

print('{} clusters of size {} or greater'.format(len(clusters), minsize))
# Out:
# 13 clusters of size 7 or greater

# %%
# For each cluster print cluster values, their frequency counts,
# and the suggested common value for the cluster.

def print_cluster(cnumber, cluster):
    print('Cluster {} (of size {})\n'.format(cnumber, len(cluster)))
    for val, count in cluster:
        print('{} ({})'.format(val, count))
    print('\nSuggested value: {}\n\n'.format(cluster.suggestion()))
    
# Sort clusters by decreasing number of distinct values.
clusters.sort(key=lambda c: len(c), reverse=True)

for i in range(len(clusters)):
    print_cluster(i + 1, clusters[i])
# Out:
# Cluster 1 (of size 8)
#
# 2ND AVE (4075)
# 2nd Ave (67751)
# 2ND  AVE (5)
# 2ND AVE. (1)
# AVE 2ND (1)
# 2ND      AVE (1)
# 2ND    AVE (2)
# 2ND       AVE (1)
#
# Suggested value: 2nd Ave
#
#
# Cluster 2 (of size 8)
#
# ST NICHOLAS AVE (2451)
# ST. NICHOLAS AVE (125)
# St Nicholas Ave (23462)
# ST, NICHOLAS AVE (1)
# ST NICHOLAS  AVE (9)
# ST NICHOLAS   AVE (1)
# ST  NICHOLAS AVE (4)
# ST. NICHOLAS  AVE (1)
#
# Suggested value: St Nicholas Ave
#
#
# Cluster 3 (of size 8)
#
# LAWRENCE ST (165)
# ST LAWRENCE (34)
# LAWRENCE  ST (1)
# Lawrence St (2368)
# ST. LAWRENCE (2)
# ST LAWRENCE ST (1)
# LAWRENCE ST. (1)
# ST. LAWRENCE ST (1)
#
# Suggested value: Lawrence St
#
#
# Cluster 4 (of size 8)
#
# ST NICHOLAS (847)
# ST NICHOLAS ST (31)
# NICHOLAS ST (27)
# ST. NICHOLAS (27)
# ST  NICHOLAS (2)
# ST NICHOLAS  ST (1)
# Nicholas St (79)
# ST. NICHOLAS ST (1)
#
# Suggested value: ST NICHOLAS
#
#
# Cluster 5 (of size 7)
#
# W 125 ST (3365)
# W 125    ST (1)
# W. 125 ST. (1)
# W .125 ST (5)
# W  125 ST (2)
# W 125  ST (1)
# W. 125 ST (3)
#
# Suggested value: W 125 ST
#
#
# Cluster 6 (of size 7)
#
# FERRY LOT 2 (743)
# FERRY LOT #2 (140)
# FERRY  LOT #2 (1)
# FERRY LOT  2 (3)
# FERRY LOT # 2 (121)
# FERRY LOT  # 2 (2)
# FERRY LOT  #2 (1)
#
# Suggested value: FERRY LOT 2
#
#
# Cluster 7 (of size 7)
#
# 3RD AVE (11554)
# 3rd Ave (148186)
# 3RD  AVE (8)
# 3RD AVE. (1)
# 3RD       AVE (1)
# 3RD     AVE (2)
# 3RD      AVE (1)
#
# Suggested value: 3rd Ave
#
#
# Cluster 8 (of size 7)
#
# CONEY ISLAND AVE (3618)
# CONEY ISLAND  AVE (9)
# CONEY  ISLAND AVE (9)
# Coney Island Ave (35776)
# CONEY ISLAND   AVE (1)
# CONEY ISLAND AVE . (1)
# CONEY ISLAND AVE. (1)
#
# Suggested value: Coney Island Ave
#
#
# Cluster 9 (of size 7)
#
# W TREMONT AVE (110)
# W. TREMONT AVE (17)
# W W TREMONT AVE (1)
# W Tremont Ave (848)
# W  TREMONT AVE (1)
# W. TREMONT  AVE (1)
# W .TREMONT AVE (1)
#
# Suggested value: W Tremont Ave
#
#
# Cluster 10 (of size 7)
#
# LGA TERMINAL B (26)
# LGA, TERMINAL B (1)
# LGA/ TERMINAL B (1)
# TERMINAL B LGA (20)
# TERMINAL B - LGA (2)
# TERMINAL B -LGA (1)
# LGA TERMINAL B, (1)
#
# Suggested value: LGA TERMINAL B
#
#
# Cluster 11 (of size 7)
#
# EL GRANT HWY (67)
# E.L GRANT HWY (10)
# E.L. GRANT HWY (19)
# EL GRANT    HWY (1)
# EL. GRANT HWY (2)
# E/L/ GRANT HWY (1)
# E-L GRANT HWY (1)
#
# Suggested value: EL GRANT HWY
#
#
# Cluster 12 (of size 7)
#
# JOHN ST (186)
# ST JOHN (10)
# John St (4192)
# ST JOHN ST (8)
# ST. JOHN ST (1)
# ST. JOHN (1)
# JOHN ST. (1)
#
# Suggested value: John St
#
#
# Cluster 13 (of size 7)
#
# ST JOHNS PL (1478)
# ST. JOHNS PL (77)
# St Johns Pl (4816)
# ST JOHNS PL. (1)
# ST. JOHNS PL. (1)
# ST  JOHNS PL (1)
# ST JOHNS  PL (2)
#
# Suggested value: St Johns Pl

# %%
# Create mapping of common street type abbreviations to a
# standardized abbreviation. Generated from
# https://github.com/VIDA-NYU/openclean-pattern/blob/master/resources/data/street_abvs.csv

mapping = {
    'ALLEE': 'ALY',
    'ALLEY': 'ALY',
    'ALLY': 'ALY',
    'ANEX': 'ANX',
    'ANNEX': 'ANX',
    'ANNX': 'ANX',
    'ARCADE': 'ARC',
    'AV': 'AVE',
    'AVEN': 'AVE',
    'AVENU': 'AVE',
    'AVENUE': 'AVE',
    'AVN': 'AVE',
    'AVNUE': 'AVE',
    'BAYOO': 'BYU',
    'BAYOU': 'BYU',
    'BEACH': 'BCH',
    'BEND': 'BND',
    'BLUF': 'BLF',
    'BLUFF': 'BLF',
    'BLUFFS': 'BLFS',
    'BOT': 'BTM',
    'BOTTM': 'BTM',
    'BOTTOM': 'BTM',
    'BOUL': 'BLVD',
    'BOULEVARD': 'BLVD',
    'BOULV': 'BLVD',
    'BRNCH': 'BR',
    'BRANCH': 'BR',
    'BRDGE': 'BRG',
    'BRIDGE': 'BRG',
    'BROOK': 'BRK',
    'BROOKS': 'BRKS',
    'BURG': 'BG',
    'BURGS': 'BGS',
    'BYPA': 'BYP',
    'BYPAS': 'BYP',
    'BYPASS': 'BYP',
    'BYPS': 'BYP',
    'CAMP': 'CP',
    'CMP': 'CP',
    'CANYN': 'CYN',
    'CANYON': 'CYN',
    'CNYN': 'CYN',
    'CAPE': 'CPE',
    'CAUSEWAY': 'CSWY',
    'CAUSWA': 'CSWY',
    'CEN': 'CTR',
    'CENT': 'CTR',
    'CENTER': 'CTR',
    'CENTR': 'CTR',
    'CENTRE': 'CTR',
    'CNTER': 'CTR',
    'CNTR': 'CTR',
    'CENTERS': 'CTRS',
    'CIRC': 'CIR',
    'CIRCL': 'CIR',
    'CIRCLE': 'CIR',
    'CRCL': 'CIR',
    'CRCLE': 'CIR',
    'CIRCLES': 'CIRS',
    'CLIFF': 'CLF',
    'CLIFFS': 'CLFS',
    'CLUB': 'CLB',
    'COMMON': 'CMN',
    'COMMONS': 'CMNS',
    'CORNER': 'COR',
    'CORNERS': 'CORS',
    'COURSE': 'CRSE',
    'COURT': 'CT',
    'COURTS': 'CTS',
    'COVE': 'CV',
    'COVES': 'CVS',
    'CREEK': 'CRK',
    'CRESCENT': 'CRES',
    'CRSENT': 'CRES',
    'CRSNT': 'CRES',
    'CREST': 'CRST',
    'CROSSING': 'XING',
    'CRSSNG': 'XING',
    'CROSSROAD': 'XRD',
    'CROSSROADS': 'XRDS',
    'CURVE': 'CURV',
    'DALE': 'DL',
    'DAM': 'DM',
    'DIV': 'DV',
    'DIVIDE': 'DV',
    'DVD': 'DV',
    'DRIV': 'DR',
    'DRIVE': 'DR',
    'DRV': 'DR',
    'DRIVES': 'DRS',
    'ESTATE': 'EST',
    'ESTATES': 'ESTS',
    'EXP': 'EXPY',
    'EXPR': 'EXPY',
    'EXPRESS': 'EXPY',
    'EXPRESSWAY': 'EXPY',
    'EXPW': 'EXPY',
    'EXTENSION': 'EXT',
    'EXTN': 'EXT',
    'EXTNSN': 'EXT',
    'FALLS': 'FLS',
    'FERRY': 'FRY',
    'FRRY': 'FRY',
    'FIELD': 'FLD',
    'FIELDS': 'FLDS',
    'FLAT': 'FLT',
    'FLATS': 'FLTS',
    'FORD': 'FRD',
    'FORDS': 'FRDS',
    'FOREST': 'FRST',
    'FORESTS': 'FRST',
    'FORG': 'FRG',
    'FORGE': 'FRG',
    'FORGES': 'FRGS',
    'FORK': 'FRK',
    'FORKS': 'FRKS',
    'FORT': 'FT',
    'FRT': 'FT',
    'FREEWAY': 'FWY',
    'FREEWY': 'FWY',
    'FRWAY': 'FWY',
    'FRWY': 'FWY',
    'GARDEN': 'GDN',
    'GARDN': 'GDN',
    'GRDEN': 'GDN',
    'GRDN': 'GDN',
    'GARDENS': 'GDNS',
    'GRDNS': 'GDNS',
    'GATEWAY': 'GTWY',
    'GATEWY': 'GTWY',
    'GATWAY': 'GTWY',
    'GTWAY': 'GTWY',
    'GLEN': 'GLN',
    'GLENS': 'GLNS',
    'GREEN': 'GRN',
    'GREENS': 'GRNS',
    'GROV': 'GRV',
    'GROVE': 'GRV',
    'GROVES': 'GRVS',
    'HARB': 'HBR',
    'HARBOR': 'HBR',
    'HARBR': 'HBR',
    'HRBOR': 'HBR',
    'HARBORS': 'HBRS',
    'HAVEN': 'HVN',
    'HT': 'HTS',
    'HIGHWAY': 'HWY',
    'HIGHWY': 'HWY',
    'HIWAY': 'HWY',
    'HIWY': 'HWY',
    'HWAY': 'HWY',
    'HILL': 'HL',
    'HILLS': 'HLS',
    'HLLW': 'HOLW',
    'HOLLOW': 'HOLW',
    'HOLLOWS': 'HOLW',
    'HOLWS': 'HOLW',
    'ISLAND': 'IS',
    'ISLND': 'IS',
    'ISLANDS': 'ISS',
    'ISLNDS': 'ISS',
    'ISLES': 'ISLE',
    'JCTION': 'JCT',
    'JCTN': 'JCT',
    'JUNCTION': 'JCT',
    'JUNCTN': 'JCT',
    'JUNCTON': 'JCT',
    'JCTNS': 'JCTS',
    'JUNCTIONS': 'JCTS',
    'KEY': 'KY',
    'KEYS': 'KYS',
    'KNOL': 'KNL',
    'KNOLL': 'KNL',
    'KNOLLS': 'KNLS',
    'LAKE': 'LK',
    'LAKES': 'LKS',
    'LANDING': 'LNDG',
    'LNDNG': 'LNDG',
    'LANE': 'LN',
    'LIGHT': 'LGT',
    'LIGHTS': 'LGTS',
    'LOAF': 'LF',
    'LOCK': 'LCK',
    'LOCKS': 'LCKS',
    'LDGE': 'LDG',
    'LODG': 'LDG',
    'LODGE': 'LDG',
    'LOOPS': 'LOOP',
    'MANOR': 'MNR',
    'MANORS': 'MNRS',
    'MEADOW': 'MDW',
    'MDW': 'MDWS',
    'MEADOWS': 'MDWS',
    'MEDOWS': 'MDWS',
    'MILL': 'ML',
    'MILLS': 'MLS',
    'MISSN': 'MSN',
    'MSSN': 'MSN',
    'MOTORWAY': 'MTWY',
    'MNT': 'MT',
    'MOUNT': 'MT',
    'MNTAIN': 'MTN',
    'MNTN': 'MTN',
    'MOUNTAIN': 'MTN',
    'MOUNTIN': 'MTN',
    'MTIN': 'MTN',
    'MNTNS': 'MTNS',
    'MOUNTAINS': 'MTNS',
    'NECK': 'NCK',
    'ORCHARD': 'ORCH',
    'ORCHRD': 'ORCH',
    'OVL': 'OVAL',
    'OVERPASS': 'OPAS',
    'PRK': 'PARK',
    'PARKS': 'PARK',
    'PARKWAY': 'PKWY',
    'PARKWY': 'PKWY',
    'PKWAY': 'PKWY',
    'PKY': 'PKWY',
    'PARKWAYS': 'PKWY',
    'PKWYS': 'PKWY',
    'PASSAGE': 'PSGE',
    'PATHS': 'PATH',
    'PIKES': 'PIKE',
    'PINE': 'PNE',
    'PINES': 'PNES',
    'PLAIN': 'PLN',
    'PLAINS': 'PLNS',
    'PLAZA': 'PLZ',
    'PLZA': 'PLZ',
    'POINT': 'PT',
    'POINTS': 'PTS',
    'PORT': 'PRT',
    'PORTS': 'PRTS',
    'PRAIRIE': 'PR',
    'PRR': 'PR',
    'RAD': 'RADL',
    'RADIAL': 'RADL',
    'RADIEL': 'RADL',
    'RANCH': 'RNCH',
    'RANCHES': 'RNCH',
    'RNCHS': 'RNCH',
    'RAPID': 'RPD',
    'RAPIDS': 'RPDS',
    'REST': 'RST',
    'RDGE': 'RDG',
    'RIDGE': 'RDG',
    'RIDGES': 'RDGS',
    'RIVER': 'RIV',
    'RVR': 'RIV',
    'RIVR': 'RIV',
    'ROAD': 'RD',
    'ROADS': 'RDS',
    'ROUTE': 'RTE',
    'SHOAL': 'SHL',
    'SHOALS': 'SHLS',
    'SHOAR': 'SHR',
    'SHORE': 'SHR',
    'SHOARS': 'SHRS',
    'SHORES': 'SHRS',
    'SKYWAY': 'SKWY',
    'SPNG': 'SPG',
    'SPRING': 'SPG',
    'SPRNG': 'SPG',
    'SPNGS': 'SPGS',
    'SPRINGS': 'SPGS',
    'SPRNGS': 'SPGS',
    'SPURS': 'SPUR',
    'SQR': 'SQ',
    'SQRE': 'SQ',
    'SQU': 'SQ',
    'SQUARE': 'SQ',
    'SQRS': 'SQS',
    'SQUARES': 'SQS',
    'STATION': 'STA',
    'STATN': 'STA',
    'STN': 'STA',
    'STRAV': 'STRA',
    'STRAVEN': 'STRA',
    'STRAVENUE': 'STRA',
    'STRAVN': 'STRA',
    'STRVN': 'STRA',
    'STRVNUE': 'STRA',
    'STREAM': 'STRM',
    'STREME': 'STRM',
    'STREET': 'ST',
    'STRT': 'ST',
    'STR': 'ST',
    'STREETS': 'STS',
    'SUMIT': 'SMT',
    'SUMITT': 'SMT',
    'SUMMIT': 'SMT',
    'TERR': 'TER',
    'TERRACE': 'TER',
    'THROUGHWAY': 'TRWY',
    'TRACE': 'TRCE',
    'TRACES': 'TRCE',
    'TRACK': 'TRAK',
    'TRACKS': 'TRAK',
    'TRK': 'TRAK',
    'TRKS': 'TRAK',
    'TRAFFICWAY': 'TRFY',
    'TRAIL': 'TRL',
    'TRAILS': 'TRL',
    'TRLS': 'TRL',
    'TRAILER': 'TRLR',
    'TRLRS': 'TRLR',
    'TUNEL': 'TUNL',
    'TUNLS': 'TUNL',
    'TUNNEL': 'TUNL',
    'TUNNELS': 'TUNL',
    'TUNNL': 'TUNL',
    'TRNPK': 'TPKE',
    'TURNPIKE': 'TPKE',
    'TURNPK': 'TPKE',
    'UNDERPASS': 'UPAS',
    'UNION': 'UN',
    'UNIONS': 'UNS',
    'VALLEY': 'VLY',
    'VALLY': 'VLY',
    'VLLY': 'VLY',
    'VALLEYS': 'VLYS',
    'VDCT': 'VIA',
    'VIADCT': 'VIA',
    'VIADUCT': 'VIA',
    'VIEW': 'VW',
    'VIEWS': 'VWS',
    'VILL': 'VLG',
    'VILLAG': 'VLG',
    'VILLAGE': 'VLG',
    'VILLG': 'VLG',
    'VILLIAGE': 'VLG',
    'VILLAGES': 'VLGS',
    'VILLE': 'VL',
    'VIST': 'VIS',
    'VISTA': 'VIS',
    'VST': 'VIS',
    'VSTA': 'VIS',
    'WALKS': 'WALK',
    'WY': 'WAY',
    'WELL': 'WL',
    'WELLS': 'WLS',
    'E': 'EAST',
    'W': 'WEST',
    'N': 'NORTH',
    'S': 'SOUTH'
}

# %%
# Use custom key generator that normalizes street type abbreviation and
# splits strings by character type, e.g., 'W35ST' is tokenized as ['W', '35', 'ST']

from openclean.function.token.base import Tokens, UpdateTokens
from openclean.function.token.filter import TokenFilter
from openclean.function.token.split import ChartypeSplit
from openclean.function.value.mapping import Standardize
from openclean.function.value.text import AlphaNumeric

tokenizer = Tokens(
    tokenizer=ChartypeSplit(chartypes=[str.isalpha, str.isdigit]),
    transformer=[TokenFilter(AlphaNumeric()), UpdateTokens(Standardize(mapping))],
    delim=' ',
    sort=True,
    unique=False
)

# This specialized tokenizer is now also included in openclean.
#from openclean.function.value.key.geo import USStreetNameKey
#tokenizer = USStreetNameKey()

clusters = key_collision(values=streets, func=tokenizer, minsize=minsize, threads=4)

print('{} clusters of size {} or greater'.format(len(clusters), minsize))
# Out:
# 532 clusters of size 7 or greater

# %%
# Print the top 25 clusters (in number of distinct values)

    
# Sort clusters by decreasing number of distinct values.
clusters.sort(key=lambda c: len(c), reverse=True)

for i in range(25):
    print_cluster(i + 1, clusters[i])
# Out:
# Cluster 1 (of size 23)
#
# W 125 ST (3365)
# W 125    ST (1)
# W 125 STREET (451)
# WEST 125 ST (522)
# WEST 125 STREET (354)
# W 125 STR (2)
# W. 125 ST. (1)
# WEST  125 ST (1)
# W .125 ST (5)
# W.125 ST (11)
# W  125 ST (2)
# W.125 STREET (1)
# W125 ST (15)
# W125 STREET (1)
# W 125  ST (1)
# W      125ST (1)
# WEST 125 STR (1)
# W 125ST (9)
# WEST 125ST (5)
# W. 125 ST (3)
# W125ST (9)
# WEST 125STREET (1)
# W 125STREET (1)
#
# Suggested value: W 125 ST
#
#
# Cluster 2 (of size 20)
#
# W 116 ST (1412)
# W 116ST (14)
# W 116 STREET (277)
# W.116 ST (15)
# W 116  STREET (3)
# WEST 116 STREET (47)
# WEST 116 ST (88)
# W 116 STR (3)
# W. 116 ST (3)
# W 116  ST (1)
# W  116 ST (1)
# W116 ST (10)
# W116ST (1)
# WEST 116ST (1)
# W .116 ST (2)
# WEST116 ST (1)
# WEST  116 ST (1)
# W 116STREET (1)
# W116 STREET (2)
# W .116 STREET (1)
#
# Suggested value: W 116 ST
#
#
# Cluster 3 (of size 19)
#
# W 43 STREET (200)
# W 43 ST (1666)
# WEST 43 STREET (425)
# WEST 43 ST (366)
# W 43ST (11)
# WEST  43 ST (1)
# W.43 STREET (3)
# W.43 ST (9)
# WEST 43ST (10)
# W43 ST (9)
# W. 43 STREET (3)
# W43ST (1)
# W. 43 ST (1)
# W 43  STREET (1)
# W  43 ST (1)
# WEST 43  STREET (1)
# WEST 43  ST (1)
# W .43 ST (1)
# WEST  43ST (1)
#
# Suggested value: W 43 ST
#
#
# Cluster 4 (of size 18)
#
# W 145 ST (1107)
# W 145 STREET (170)
# W  145 ST (1)
# WEST 145 STREET (89)
# WEST 145 ST (117)
# W .145 ST (1)
# W 145 STR (16)
# W. 145 ST. (1)
# W. 145 STREET (1)
# W.145 STREET (2)
# W145 ST (4)
# W.145 ST (4)
# WEST 145ST (5)
# W145ST (1)
# WEST145 STREET (1)
# W 145ST (3)
# W 145 ST` (1)
# W .145 STREET (1)
#
# Suggested value: W 145 ST
#
#
# Cluster 5 (of size 17)
#
# W 168 STREET (235)
# WEST 168 STREET (127)
# W 168 ST (482)
# WEST 168 ST (214)
# W 168  STREET (1)
# W.168 ST (3)
# W  168 STREET (1)
# W168 STREET (1)
# W.168 STREET (4)
# W .168 ST (1)
# W 168ST (3)
# WEST 168ST (2)
# W  168 ST (1)
# W168ST (2)
# W168 ST (2)
# WEST  168 ST (1)
# WEST168 ST (1)
#
# Suggested value: W 168 ST
#
#
# Cluster 6 (of size 17)
#
# W 39 ST (1035)
# WEST 39 STREET (118)
# W 39 STREET (108)
# WEST 39 ST (137)
# W 39 STRT (7)
# W 39  ST (2)
# W39 ST (5)
# W 39ST (4)
# W 39 STR (2)
# W.39 ST (4)
# W .39 STREET (1)
# W.39 STREET (2)
# WEST 39 STR (2)
# W. 39 ST (4)
# W .39 ST (1)
# WEST39 STREET (1)
# WEST   39 STREET (1)
#
# Suggested value: W 39 ST
#
#
# Cluster 7 (of size 17)
#
# W 42 ST (1039)
# WEST 42 STREET (191)
# WEST 42 ST (116)
# W 42 STREET (104)
# W42 ST (2)
# W.42 STREET (1)
# W .42 ST (5)
# W 42ST (4)
# W 42  ST (2)
# WEST 42 ST. (1)
# W. 42 STREET (3)
# W.42 ST (14)
# WEST  42 STREET (2)
# WEST 42ST (4)
# WEST 42STREET (1)
# W . 42 ST (1)
# W42ST (1)
#
# Suggested value: W 42 ST
#
#
# Cluster 8 (of size 17)
#
# W 47 ST (2110)
# WEST 47 STREET (100)
# WEST 47 ST (101)
# W 47 STREET (86)
# W 47ST (24)
# W 47  STREET (2)
# W  47 ST (2)
# W.47 STREET (1)
# W.47 ST (14)
# W47ST (2)
# W 47 STR (1)
# W .47 ST (2)
# W 47  ST (2)
# W47 ST (5)
# W 47 ST. (1)
# W 47STREET (1)
# WEST  47 ST (1)
#
# Suggested value: W 47 ST
#
#
# Cluster 9 (of size 17)
#
# EAST TREMONT AVE (261)
# E TREMONT AVE (751)
# EAST TREMONT AVENUE (37)
# E TREMONT AV (39)
# E. TREMONT AVE (60)
# E. TREMONT AV (9)
# E.TREMONT AVE (29)
# E TREMONT AVE. (1)
# EAST TREMONT AV (8)
# E TREMONT AVENUE (10)
# E TREMONT  AVE (1)
# EAST TREMONT  AVE (1)
# EAST  TREMONT AVE (1)
# E. TREMONT AVENUE (1)
# E TREMONT  AV (1)
# E  TREMONT AVE (2)
# E.TREMONT AV (2)
#
# Suggested value: E TREMONT AVE
#
#
# Cluster 10 (of size 16)
#
# W 139 STREET (149)
# W 139  ST (1)
# W 139 ST (279)
# WEST 139 ST (37)
# WEST 139 STREET (34)
# W.139 ST (2)
# W 139 STREET. (1)
# W 139 ST. (1)
# W139 ST (2)
# W.139 STREET (1)
# W .139 STREET (2)
# W  139 STREET (1)
# WEST   139 STREET (1)
# W 139ST (1)
# W 139 STR (1)
# W. 139 STREET (1)
#
# Suggested value: W 139 ST
#
#
# Cluster 11 (of size 16)
#
# E 23 ST (672)
# EAST 23 ST (77)
# E 23 STREET (46)
# EAST 23 STREET (29)
# E.23 ST (5)
# E23 ST (6)
# E23ST (1)
# E 23ST (3)
# E 23 STR (2)
# E  23 ST (1)
# E. 23 ST (1)
# E 23 ST. (1)
# E. 23 ST. (1)
# E-23 ST (1)
# E .23 ST (1)
# EAST 23ST (1)
#
# Suggested value: E 23 ST
#
#
# Cluster 12 (of size 16)
#
# W 35 ST (1063)
# WEST 35 ST (97)
# WEST 35 STREET (59)
# W 35 STREET (72)
# W35 ST (3)
# W 35ST (5)
# W 35 STRT (1)
# W.35 ST (4)
# W 35   ST (1)
# W35ST (1)
# W  35 ST (2)
# W 35 STR (2)
# W .35 ST (2)
# WEST 35ST (1)
# W. 35 ST (1)
# W 35STREET (1)
#
# Suggested value: W 35 ST
#
#
# Cluster 13 (of size 16)
#
# W 72 ST (994)
# WEST 72 STREET (17)
# W 72 STREET (61)
# WEST 72 ST (27)
# W 72 STR (4)
# 72 W ST (1)
# W .72 ST (5)
# W.72 ST (6)
# W  72 ST (3)
# W 72  ST (1)
# W 72ST (7)
# W.72 STREET (1)
# W72ST (1)
# W. 72 ST (1)
# WEST 72 STR (1)
# W72 ST (1)
#
# Suggested value: W 72 ST
#
#
# Cluster 14 (of size 16)
#
# EAST NEW YORK AVE (286)
# E NEW YORK AVE (136)
# EAST NEW YORK AVENUE (15)
# E NEW YORK AV (30)
# EAST NEW YORK AV (12)
# E.NEW YORK AVE (6)
# E. NEW YORK AVE (5)
# EAST NEW YORK  AVE (2)
# EAST NEW YORK    AVE (1)
# E.NEW YORK AV (2)
# E  NEW YORK AVE (1)
# E . NEW YORK AVE (1)
# E. NEW YORK AVENUE (1)
# EAST  NEW YORK AVE (2)
# E. NEW YORK AV (4)
# E  NEW YORK AV (2)
#
# Suggested value: EAST NEW YORK AVE
#
#
# Cluster 15 (of size 16)
#
# FORT WASHINGTON AVE (255)
# FRT WASHINGTON AVE (3)
# FT WASHINGTON AVE (615)
# FT WASHINGTON AV (28)
# FORT WASHINGTON AV (21)
# FT. WASHINGTON AVE (40)
# FORT WASHINGTON AVEN (14)
# FT. WASHINGTON AV (3)
# FT WASHINGTON AVENUE (58)
# FRT WASHINGTON AVENU (1)
# FT.WASHINGTON AVE (6)
# FORT WASHINGTON  AVE (5)
# FT WASHINGTON  AVE (4)
# FT  WASHINGTON AVE (1)
# FT WASHINGTON  AV (1)
# FT WASHINGTON  AVENU (1)
#
# Suggested value: FT WASHINGTON AVE
#
#
# Cluster 16 (of size 16)
#
# FT HAMILTON PKWY (576)
# FORT HAMILTON PKWY (200)
# FORT HAMILTON PKWAY (12)
# FT HAMILTON  PKWY (6)
# FT. HAMILTON PKWY (22)
# FT.HAMILTON PKWY (8)
# FT.HAMILTON PKY (1)
# FT HAMILTON PKY (31)
# FT HAMILTON PARKWAY (4)
# FT HAMILTON PARKWY (1)
# FORT HAMILTON PKY (12)
# FT HAMILTON PKWAY (2)
# FORT  HAMILTON PKWY (1)
# FORT HAMILTON  PKWY (1)
# FRT HAMILTON PKWY (1)
# FORT HAMILTON PKY . (1)
#
# Suggested value: FT HAMILTON PKWY
#
#
# Cluster 17 (of size 15)
#
# E 116 ST (1020)
# EAST 116 ST (185)
# E 116 STREET (151)
# E116ST (2)
# EAST 116 STREET (66)
# E .116 STREET (3)
# E. 116 ST (1)
# E.116 ST (9)
# E.116 STREET (5)
# E .116 ST (3)
# E 116  STREET (1)
# E  116 ST (1)
# E116 ST (15)
# E 116ST (5)
# EAST116STREET (1)
#
# Suggested value: E 116 ST
#
#
# Cluster 18 (of size 15)
#
# W 16 ST (787)
# WEST 16 ST (34)
# W 16 STREET (70)
# WEST 16 STREET (144)
# W.16 ST (3)
# WEST  16 ST (1)
# WEST 16 STR (1)
# W16ST (2)
# W 16 STR (1)
# W 16ST (5)
# W16 ST (1)
# W .16 STREET (3)
# W.16 STREET (1)
# W .16 ST (1)
# WEST 16STREET (1)
#
# Suggested value: W 16 ST
#
#
# Cluster 19 (of size 15)
#
# E 20TH ST (125)
# EAST 20TH STREET (145)
# EAST 20TH ST (99)
# E 20TH STREET (38)
# E 20TH STR (6)
# E 20TH  ST (1)
# E. 20 TH ST (2)
# E 20 TH ST (2)
# E  20TH ST (2)
# EAST 20TH  STREET (1)
# EAST20TH STREET (3)
# E20TH ST (1)
# E.20TH ST (1)
# EAST  20TH STREET (1)
# EAST 20 TH ST (1)
#
# Suggested value: EAST 20TH STREET
#
#
# Cluster 20 (of size 15)
#
# W 31 ST (552)
# WEST 31 STREET (118)
# WEST 31 ST (99)
# W 31 STREET (66)
# WEST 31  STREET (1)
# W 31 STRT (11)
# W 31ST (8)
# W.31 ST (6)
# W. 31 ST (2)
# WEST 31ST (1)
# W 31 STR (10)
# W .31 ST (2)
# W31 ST (1)
# W 31  ST (1)
# W. 31 ST. (1)
#
# Suggested value: W 31 ST
#
#
# Cluster 21 (of size 15)
#
# W 46 ST (1142)
# WEST 46 STREET (112)
# WEST 46 ST (96)
# W 46 STREET (141)
# W.46 ST (26)
# W .46 ST (6)
# W46 ST (5)
# W 46ST (8)
# W.46 STREET (5)
# W46ST (3)
# WEST 46ST (1)
# W  46 ST (1)
# W 46  ST (1)
# W 46 ST+ (1)
# WEST46 ST (1)
#
# Suggested value: W 46 ST
#
#
# Cluster 22 (of size 15)
#
# E 96 ST (765)
# E 96 STREET (58)
# EAST 96 ST (58)
# EAST 96 STREET (77)
# E 96 STR (8)
# E .96 ST (1)
# E96 STR (1)
# E.96 ST (2)
# E  96 ST (1)
# EAST 96ST (2)
# E 96ST (8)
# E 96 ST. (1)
# E96 ST (3)
# E 96  ST (1)
# E .96 STREET (1)
#
# Suggested value: E 96 ST
#
#
# Cluster 23 (of size 15)
#
# CONEY ISLAND AVE (3618)
# CONEY ISLAND AV (450)
# CONEY ISLAND AVENUE (35)
# CONEY ISLAND  AVE (9)
# CONEY IS AVE (77)
# CONEY  ISLAND AVE (9)
# CONEY IS AV (5)
# CONEY ISLAND AV+ (1)
# CONEY IS. AVE (4)
# CONEY ISLAND   AVE (1)
# CONEY ISLAND AVE . (1)
# CONEY ISLAND  AV (1)
# CONEY ISLAND AVE. (1)
# CONEY  IS AVE (1)
# CONEY IS  AVE (1)
#
# Suggested value: CONEY ISLAND AVE
#
#
# Cluster 24 (of size 15)
#
# ST NICHOLAS AVE (2451)
# ST NICHOLAS AV (112)
# ST NICHOLAS AVENUE (105)
# ST.NICHOLAS AVE (81)
# ST. NICHOLAS AVE (125)
# ST. NICHOLAS AVENUE (4)
# ST.NICHOLAS AVENUE (3)
# ST, NICHOLAS AVE (1)
# ST NICHOLAS  AVE (9)
# ST.NICHOLAS AV (9)
# ST NICHOLAS   AVE (1)
# ST NICHOLAS  AVENUE (1)
# ST  NICHOLAS AVE (4)
# ST. NICHOLAS AV (4)
# ST. NICHOLAS  AVE (1)
#
# Suggested value: ST NICHOLAS AVE
#
#
# Cluster 25 (of size 14)
#
# W 135 ST (557)
# W 135 STREET (128)
# WEST 135 ST (52)
# W .135 ST (1)
# WEST 135 STREET (67)
# W  135 ST (2)
# W .135 STREET (1)
# W 135 STR (7)
# W135 ST (3)
# W.135 ST (1)
# W 135ST (5)
# W 135STREET (1)
# W135ST (2)
# W135 STREET (1)
#
# Suggested value: W 135 ST
